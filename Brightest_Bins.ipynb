# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#getting and sorting data
data = np.loadtxt(r"C:\Users\samlo\Downloads\IC79-2010-events.txt", skiprows=1)
data = data[data[:,1].argsort()]  #Selects column number
data = data.transpose() #flipping array

# %%
xedges = np.linspace(0, 360, num=720)
yedges = np.linspace(-90, 90, num=360)

x = data[3]
y = data[4]

H, xedges, yedges = np.histogram2d(x, y, bins=(xedges, yedges))
fig, ax = plt.subplots()
X, Y = np.meshgrid(xedges, yedges)
ax.pcolormesh(X, Y, H.T)
plt.show()

# %%
H.max()
# Out:
# 7.0

# %%
np.where(H == 7.0)
# Out:
# (array([122, 551], dtype=int64), array([178, 175], dtype=int64))

# %%
#Source 1 is at (ra, dec) = (275, -29)
#Source 2 is at (87, -1)

# %%
J1820.3+3625
